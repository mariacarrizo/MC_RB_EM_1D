# %% [markdown]
# # Visualize case B1 results
#
# Date created: 23/04/2024
# Author: @mariacarrizo

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import sys
sys.path.insert(1, '../../src')

from Plots import Plot_Models_3Lay_QIP, Plot_Models_3Lay, Plot_Noise_3Lay, Plot_Models_GSGN
#from EM1D import EMf_3Lay_HVP

# %%
# Import Models

model_true_B1_1 = np.load('models/model_synth_B1_1.npy')
model_true_B1_2 = np.load('models/model_synth_B1_2.npy')
model_true_B1_3 = np.load('models/model_synth_B1_3.npy')
model_true_B1_4 = np.load('models/model_synth_B1_4.npy')

model_true_B1_1[:,2:] = model_true_B1_1[:,2:]*1000
model_true_B1_2[:,2:] = model_true_B1_2[:,2:]*1000
model_true_B1_3[:,2:] = model_true_B1_3[:,2:]*1000
model_true_B1_4[:,2:] = model_true_B1_4[:,2:]*1000

# Results from global search
model_GS_B1_1 = np.load('results/model_GS_B1_1.npy')
model_GS_B1_2 = np.load('results/model_GS_B1_2.npy')
model_GS_B1_3 = np.load('results/model_GS_B1_3.npy')
model_GS_B1_4 = np.load('results/model_GS_B1_4.npy')

model_GS_B1_1[:,2:] = model_GS_B1_1[:,2:]*1000
model_GS_B1_2[:,2:] = model_GS_B1_2[:,2:]*1000
model_GS_B1_3[:,2:] = model_GS_B1_3[:,2:]*1000
model_GS_B1_4[:,2:] = model_GS_B1_4[:,2:]*1000

# Results from Gauss-Newton
model_GN_B1_1 = np.load('results/model_GN_B1_1.npy')
model_GN_B1_2 = np.load('results/model_GN_B1_2.npy')
model_GN_B1_3 = np.load('results/model_GN_B1_3.npy')
model_GN_B1_4 = np.load('results/model_GN_B1_4.npy')

model_GN_B1_1[:,2:] =  model_GN_B1_1[:,2:]*1000 
model_GN_B1_2[:,2:] =  model_GN_B1_2[:,2:]*1000 
model_GN_B1_3[:,2:] =  model_GN_B1_3[:,2:]*1000 
model_GN_B1_4[:,2:] =  model_GN_B1_4[:,2:]*1000 

# Results from global search Q
model_GS_Q_B1_1 = np.load('results/model_GS_Q_B1_1.npy')
model_GS_Q_B1_2 = np.load('results/model_GS_Q_B1_2.npy')
model_GS_Q_B1_3 = np.load('results/model_GS_Q_B1_3.npy')
model_GS_Q_B1_4 = np.load('results/model_GS_Q_B1_4.npy')

model_GS_Q_B1_1[:,2:] = model_GS_Q_B1_1[:,2:]*1000
model_GS_Q_B1_2[:,2:] = model_GS_Q_B1_2[:,2:]*1000
model_GS_Q_B1_3[:,2:] = model_GS_Q_B1_3[:,2:]*1000
model_GS_Q_B1_4[:,2:] = model_GS_Q_B1_4[:,2:]*1000

# Results from Gauss-Newton Q
model_GN_Q_B1_1 = np.load('results/model_GN_Q_B1_1.npy')
model_GN_Q_B1_2 = np.load('results/model_GN_Q_B1_2.npy')
model_GN_Q_B1_3 = np.load('results/model_GN_Q_B1_3.npy')
model_GN_Q_B1_4 = np.load('results/model_GN_Q_B1_4.npy')

model_GN_Q_B1_1[:,2:] = model_GN_Q_B1_1[:,2:]*1000
model_GN_Q_B1_2[:,2:] = model_GN_Q_B1_2[:,2:]*1000
model_GN_Q_B1_3[:,2:] = model_GN_Q_B1_3[:,2:]*1000
model_GN_Q_B1_4[:,2:] = model_GN_Q_B1_4[:,2:]*1000

# Results from global search IP
model_GS_IP_B1_1 = np.load('results/model_GS_IP_B1_1.npy')
model_GS_IP_B1_2 = np.load('results/model_GS_IP_B1_2.npy')
model_GS_IP_B1_3 = np.load('results/model_GS_IP_B1_3.npy')
model_GS_IP_B1_4 = np.load('results/model_GS_IP_B1_4.npy')

model_GS_IP_B1_1[:,2:] = model_GS_IP_B1_1[:,2:]*1000
model_GS_IP_B1_2[:,2:] = model_GS_IP_B1_2[:,2:]*1000
model_GS_IP_B1_3[:,2:] = model_GS_IP_B1_3[:,2:]*1000
model_GS_IP_B1_4[:,2:] = model_GS_IP_B1_4[:,2:]*1000

# Results from Gauss-Newton IP
model_GN_IP_B1_1 = np.load('results/model_GN_IP_B1_1.npy')
model_GN_IP_B1_2 = np.load('results/model_GN_IP_B1_2.npy')
model_GN_IP_B1_3 = np.load('results/model_GN_IP_B1_3.npy')
model_GN_IP_B1_4 = np.load('results/model_GN_IP_B1_4.npy')

model_GN_IP_B1_1[:,2:] = model_GN_IP_B1_1[:,2:]*1000
model_GN_IP_B1_2[:,2:] = model_GN_IP_B1_2[:,2:]*1000
model_GN_IP_B1_3[:,2:] = model_GN_IP_B1_3[:,2:]*1000
model_GN_IP_B1_4[:,2:] = model_GN_IP_B1_4[:,2:]*1000

# Results from Global search + Gauss-Newton inversion
model_GSGN_B1_1 = np.load('results/model_GSGN_B1_1.npy')
model_GSGN_B1_2 = np.load('results/model_GSGN_B1_2.npy')
model_GSGN_B1_3 = np.load('results/model_GSGN_B1_3.npy')
model_GSGN_B1_4 = np.load('results/model_GSGN_B1_4.npy')

model_GSGN_B1_1[:,2:] = model_GSGN_B1_1[:,2:]*1000
model_GSGN_B1_2[:,2:] = model_GSGN_B1_2[:,2:]*1000
model_GSGN_B1_3[:,2:] = model_GSGN_B1_3[:,2:]*1000
model_GSGN_B1_4[:,2:] = model_GSGN_B1_4[:,2:]*1000

# %%
# Vector of 1D positions distance
x = np.linspace(0, len(model_true_B1_1), len(model_true_B1_1))

# True model 
z1 = model_true_B1_1[:,0] # Thickness of first layer
z2 = model_true_B1_1[:,1] # Thickness of second layer

# %%
# Import Data
data_true_B1_1 = np.load('data/data_synth_B1_1.npy')*1000
data_true_B1_2 = np.load('data/data_synth_B1_2.npy')*1000
data_true_B1_3 = np.load('data/data_synth_B1_3.npy')*1000
data_true_B1_4 = np.load('data/data_synth_B1_4.npy')*1000

data_GS_B1_1 = np.load('data/data_GS_B1_1.npy')*1000
data_GS_B1_2 = np.load('data/data_GS_B1_2.npy')*1000
data_GS_B1_3 = np.load('data/data_GS_B1_3.npy')*1000
data_GS_B1_4 = np.load('data/data_GS_B1_4.npy')*1000

data_GS_Q_B1_1 = np.load('data/data_GS_Q_B1_1.npy')*1000
data_GS_Q_B1_2 = np.load('data/data_GS_Q_B1_2.npy')*1000
data_GS_Q_B1_3 = np.load('data/data_GS_Q_B1_3.npy')*1000
data_GS_Q_B1_4 = np.load('data/data_GS_Q_B1_4.npy')*1000

data_GS_IP_B1_1 = np.load('data/data_GS_IP_B1_1.npy')*1000
data_GS_IP_B1_2 = np.load('data/data_GS_IP_B1_2.npy')*1000
data_GS_IP_B1_3 = np.load('data/data_GS_IP_B1_3.npy')*1000
data_GS_IP_B1_4 = np.load('data/data_GS_IP_B1_4.npy')*1000

data_GN_B1_1 = np.load('data/data_GN_B1_1.npy')*1000
data_GN_B1_2 = np.load('data/data_GN_B1_2.npy')*1000
data_GN_B1_3 = np.load('data/data_GN_B1_3.npy')*1000
data_GN_B1_4 = np.load('data/data_GN_B1_4.npy')*1000

data_GN_Q_B1_1 = np.load('data/data_GN_Q_B1_1.npy')*1000
data_GN_Q_B1_2 = np.load('data/data_GN_Q_B1_2.npy')*1000
data_GN_Q_B1_3 = np.load('data/data_GN_Q_B1_3.npy')*1000
data_GN_Q_B1_4 = np.load('data/data_GN_Q_B1_4.npy')*1000

data_GN_IP_B1_1 = np.load('data/data_GN_IP_B1_1.npy')*1000
data_GN_IP_B1_2 = np.load('data/data_GN_IP_B1_2.npy')*1000
data_GN_IP_B1_3 = np.load('data/data_GN_IP_B1_3.npy')*1000
data_GN_IP_B1_4 = np.load('data/data_GN_IP_B1_4.npy')*1000

# %% [markdown]
# # Results estimations using Q + IP

# %%
Plot_Models_3Lay_QIP(model_true_B1_1, model_GS_B1_1, model_GN_B1_1, data_true_B1_1, data_GS_B1_1, data_GN_B1_1, 
                     x, z1, z2, case='B1-1')
#plt.savefig('figures/B1-1_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_3Lay_QIP(model_true_B1_2, model_GS_B1_2, model_GN_B1_2, data_true_B1_2, data_GS_B1_2, data_GN_B1_2,  
                    x, z1, z2, case='B1-2')
#plt.savefig('figures/B1-2_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_3Lay_QIP(model_true_B1_3, model_GS_B1_3, model_GN_B1_3, data_true_B1_3, data_GS_B1_3, data_GN_B1_3, 
                    x, z1, z2, case='B1-3')
#plt.savefig('figures/B1-3_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_3Lay_QIP(model_true_B1_4, model_GS_B1_4, model_GN_B1_4, data_true_B1_4, data_GS_B1_4, data_GN_B1_4,
                    x, z1, z2, case='B1-4')
#plt.savefig('figures/B1-4_GSvsGN.png', bbox_inches='tight')

# %% [markdown]
# # Results using Q only

# %%
Plot_Models_3Lay(model_true_B1_1, model_GS_Q_B1_1, model_GN_Q_B1_1, data_true_B1_1[:,:9], data_GS_Q_B1_1, data_GN_Q_B1_1, 
                 x, z1, z2, data_type='Quadrature', case='A1-1')
#plt.savefig('figures/F1_Q.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_2, model_GS_Q_B1_2, model_GN_Q_B1_2, data_true_B1_2[:,:9], data_GS_Q_B1_2, data_GN_Q_B1_2, 
                 x, z1, z2, data_type='Quadrature', case='A1-2')
#plt.savefig('figures/F2_Q.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_3, model_GS_Q_B1_3, model_GN_Q_B1_3, data_true_B1_3[:,:9], data_GS_Q_B1_3, data_GN_Q_B1_3, 
                 x, z1, z2, data_type='Quadrature', case='A1-3')
#plt.savefig('figures/F3_Q.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_4, model_GS_Q_B1_4, model_GN_Q_B1_4, data_true_B1_4[:,:9], data_GS_Q_B1_4, data_GN_Q_B1_4,
                 x, z1, z2, data_type='Quadrature', case='A1-4')
#plt.savefig('figures/F4_Q.png', bbox_inches='tight')

# %% [markdown]
# # Results using IP only

# %%
Plot_Models_3Lay(model_true_B1_1, model_GS_IP_B1_1, model_GN_IP_B1_1, data_true_B1_1[:,9:], data_GS_IP_B1_1, data_GN_IP_B1_1, 
                 x, z1, z2, data_type='In Phase', case='A1-1')
#plt.savefig('figures/F1_IP.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_2, model_GS_IP_B1_2, model_GN_IP_B1_2, data_true_B1_2[:,9:], data_GS_IP_B1_2, data_GN_IP_B1_2, 
                 x, z1, z2, data_type='In Phase', case='A1-2')
#plt.savefig('figures/F2_IP.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_3, model_GS_IP_B1_3, model_GN_IP_B1_3, data_true_B1_3[:,9:], data_GS_IP_B1_3, data_GN_IP_B1_3, 
                 x, z1, z2, data_type='In Phase', case='A1-3')
#plt.savefig('figures/F3_IP.png', bbox_inches='tight')

# %%
Plot_Models_3Lay(model_true_B1_4, model_GS_IP_B1_4, model_GN_IP_B1_4, data_true_B1_4[:,9:], data_GS_IP_B1_4, data_GN_IP_B1_4, 
                 x, z1, z2, data_type='In Phase', case='A1-4')
#plt.savefig('figures/F4_IP.png', bbox_inches='tight')

# %% [markdown]
# ## Noise results

# %%
# Load results

# Global search
model_GS_n2_B1_1 = np.load('results/model_GS_n2_B1_1.npy')
model_GS_n2_B1_2 = np.load('results/model_GS_n2_B1_2.npy')
model_GS_n2_B1_3 = np.load('results/model_GS_n2_B1_3.npy')
model_GS_n2_B1_4 = np.load('results/model_GS_n2_B1_4.npy')

model_GS_n2_B1_1[:,2:] = model_GS_n2_B1_1[:,2:]*1000
model_GS_n2_B1_2[:,2:] = model_GS_n2_B1_2[:,2:]*1000
model_GS_n2_B1_3[:,2:] = model_GS_n2_B1_3[:,2:]*1000
model_GS_n2_B1_4[:,2:] = model_GS_n2_B1_4[:,2:]*1000

model_GS_n5_B1_1 = np.load('results/model_GS_n5_B1_1.npy')
model_GS_n5_B1_2 = np.load('results/model_GS_n5_B1_2.npy')
model_GS_n5_B1_3 = np.load('results/model_GS_n5_B1_3.npy')
model_GS_n5_B1_4 = np.load('results/model_GS_n5_B1_4.npy')

model_GS_n5_B1_1[:,2:] = model_GS_n5_B1_1[:,2:]*1000
model_GS_n5_B1_2[:,2:] = model_GS_n5_B1_2[:,2:]*1000
model_GS_n5_B1_3[:,2:] = model_GS_n5_B1_3[:,2:]*1000
model_GS_n5_B1_4[:,2:] = model_GS_n5_B1_4[:,2:]*1000

model_GS_n10_B1_1 = np.load('results/model_GS_n10_B1_1.npy')
model_GS_n10_B1_2 = np.load('results/model_GS_n10_B1_2.npy')
model_GS_n10_B1_3 = np.load('results/model_GS_n10_B1_3.npy')
model_GS_n10_B1_4 = np.load('results/model_GS_n10_B1_4.npy')

model_GS_n10_B1_1[:,2:] = model_GS_n10_B1_1[:,2:]*1000
model_GS_n10_B1_2[:,2:] = model_GS_n10_B1_2[:,2:]*1000
model_GS_n10_B1_3[:,2:] = model_GS_n10_B1_3[:,2:]*1000
model_GS_n10_B1_4[:,2:] = model_GS_n10_B1_4[:,2:]*1000

# Gauss-Newton
model_GN_n2_B1_1 = np.load('results/model_GN_n2_B1_1.npy')
model_GN_n2_B1_2 = np.load('results/model_GN_n2_B1_2.npy')
model_GN_n2_B1_3 = np.load('results/model_GN_n2_B1_3.npy')
model_GN_n2_B1_4 = np.load('results/model_GN_n2_B1_4.npy')

model_GN_n2_B1_1[:,2:] = model_GN_n2_B1_1[:,2:]*1000
model_GN_n2_B1_2[:,2:] = model_GN_n2_B1_2[:,2:]*1000
model_GN_n2_B1_3[:,2:] = model_GN_n2_B1_3[:,2:]*1000
model_GN_n2_B1_4[:,2:] = model_GN_n2_B1_4[:,2:]*1000

model_GN_n5_B1_1 = np.load('results/model_GN_n5_B1_1.npy')
model_GN_n5_B1_2 = np.load('results/model_GN_n5_B1_2.npy')
model_GN_n5_B1_3 = np.load('results/model_GN_n5_B1_3.npy')
model_GN_n5_B1_4 = np.load('results/model_GN_n5_B1_4.npy')

model_GN_n5_B1_1[:,2:] = model_GN_n5_B1_1[:,2:]*1000
model_GN_n5_B1_2[:,2:] = model_GN_n5_B1_2[:,2:]*1000
model_GN_n5_B1_3[:,2:] = model_GN_n5_B1_3[:,2:]*1000
model_GN_n5_B1_4[:,2:] = model_GN_n5_B1_4[:,2:]*1000

model_GN_n10_B1_1 = np.load('results/model_GN_n10_B1_1.npy')
model_GN_n10_B1_2 = np.load('results/model_GN_n10_B1_2.npy')
model_GN_n10_B1_3 = np.load('results/model_GN_n10_B1_3.npy')
model_GN_n10_B1_4 = np.load('results/model_GN_n10_B1_4.npy')

model_GN_n10_B1_1[:,2:] = model_GN_n10_B1_1[:,2:]*1000
model_GN_n10_B1_2[:,2:] = model_GN_n10_B1_2[:,2:]*1000
model_GN_n10_B1_3[:,2:] = model_GN_n10_B1_3[:,2:]*1000
model_GN_n10_B1_4[:,2:] = model_GN_n10_B1_4[:,2:]*1000

# %%
# Load true and simulated data in ppt

data_true_n2_B1_1 = np.load('data/data_n2_B1_1.npy')*1000
data_true_n2_B1_2 = np.load('data/data_n2_B1_2.npy')*1000
data_true_n2_B1_3 = np.load('data/data_n2_B1_3.npy')*1000
data_true_n2_B1_4 = np.load('data/data_n2_B1_4.npy')*1000

data_true_n5_B1_1 = np.load('data/data_n5_B1_1.npy')*1000
data_true_n5_B1_2 = np.load('data/data_n5_B1_2.npy')*1000
data_true_n5_B1_3 = np.load('data/data_n5_B1_3.npy')*1000
data_true_n5_B1_4 = np.load('data/data_n5_B1_4.npy')*1000

data_true_n10_B1_1 = np.load('data/data_n10_B1_1.npy')*1000
data_true_n10_B1_2 = np.load('data/data_n10_B1_2.npy')*1000
data_true_n10_B1_3 = np.load('data/data_n10_B1_3.npy')*1000
data_true_n10_B1_4 = np.load('data/data_n10_B1_4.npy')*1000

data_GS_n2_B1_1 = np.load('data/data_GS_n2_B1_1.npy')*1000
data_GS_n2_B1_2 = np.load('data/data_GS_n2_B1_2.npy')*1000
data_GS_n2_B1_3 = np.load('data/data_GS_n2_B1_3.npy')*1000
data_GS_n2_B1_4 = np.load('data/data_GS_n2_B1_4.npy')*1000

data_GS_n5_B1_1 = np.load('data/data_GS_n5_B1_1.npy')*1000
data_GS_n5_B1_2 = np.load('data/data_GS_n5_B1_2.npy')*1000
data_GS_n5_B1_3 = np.load('data/data_GS_n5_B1_3.npy')*1000
data_GS_n5_B1_4 = np.load('data/data_GS_n5_B1_4.npy')*1000

data_GS_n10_B1_1 = np.load('data/data_GS_n10_B1_1.npy')*1000
data_GS_n10_B1_2 = np.load('data/data_GS_n10_B1_2.npy')*1000
data_GS_n10_B1_3 = np.load('data/data_GS_n10_B1_3.npy')*1000
data_GS_n10_B1_4 = np.load('data/data_GS_n10_B1_4.npy')*1000

data_GN_n2_B1_1 = np.load('data/data_GN_n2_B1_1.npy')*1000
data_GN_n2_B1_2 = np.load('data/data_GN_n2_B1_2.npy')*1000
data_GN_n2_B1_3 = np.load('data/data_GN_n2_B1_3.npy')*1000
data_GN_n2_B1_4 = np.load('data/data_GN_n2_B1_4.npy')*1000

data_GN_n5_B1_1 = np.load('data/data_GN_n5_B1_1.npy')*1000
data_GN_n5_B1_2 = np.load('data/data_GN_n5_B1_2.npy')*1000
data_GN_n5_B1_3 = np.load('data/data_GN_n5_B1_3.npy')*1000
data_GN_n5_B1_4 = np.load('data/data_GN_n5_B1_4.npy')*1000

data_GN_n10_B1_1 = np.load('data/data_GN_n10_B1_1.npy')*1000
data_GN_n10_B1_2 = np.load('data/data_GN_n10_B1_2.npy')*1000
data_GN_n10_B1_3 = np.load('data/data_GN_n10_B1_3.npy')*1000
data_GN_n10_B1_4 = np.load('data/data_GN_n10_B1_4.npy')*1000

# %%
Plot_Noise_3Lay(model_true_B1_1, model_GS_n2_B1_1, model_GS_n5_B1_1, model_GS_n10_B1_1,
                model_GN_n2_B1_1, model_GN_n5_B1_1, model_GN_n10_B1_1 ,
                data_true_B1_1, data_GS_n2_B1_1, data_GS_n5_B1_1, data_GS_n10_B1_1,
                data_GN_n2_B1_1, data_GN_n5_B1_1, data_GN_n10_B1_1, x, z1, z2)
#plt.savefig('figures/F1_noise.png', bbox_inches='tight')

# %%
Plot_Noise_3Lay(model_true_B1_2, model_GS_n2_B1_2, model_GS_n5_B1_2, model_GS_n10_B1_2,
                model_GN_n2_B1_2, model_GN_n5_B1_2, model_GN_n10_B1_2,
                data_true_B1_2, data_GS_n2_B1_2, data_GS_n5_B1_2, data_GS_n10_B1_2,
                data_GN_n2_B1_2, data_GN_n5_B1_2, data_GN_n10_B1_2, x, z1, z2)
#plt.savefig('figures/F2_noise.png', bbox_inches='tight')

# %%
Plot_Noise_3Lay(model_true_B1_3, model_GS_n2_B1_3, model_GS_n5_B1_3, model_GS_n10_B1_3,
                model_GN_n2_B1_3, model_GN_n5_B1_3, model_GN_n10_B1_3,
                data_true_B1_3, data_GS_n2_B1_3, data_GS_n5_B1_3, data_GS_n10_B1_3,
                data_GN_n2_B1_3, data_GN_n5_B1_3, data_GN_n10_B1_3, x, z1, z2)
#plt.savefig('figures/F3_noise.png', bbox_inches='tight')

# %%
Plot_Noise_3Lay(model_true_B1_4, model_GS_n2_B1_4, model_GS_n5_B1_4, model_GS_n10_B1_4,
                model_GN_n2_B1_4, model_GN_n5_B1_4, model_GN_n10_B1_4,
                data_true_B1_4, data_GS_n2_B1_4, data_GS_n5_B1_4, data_GS_n10_B1_4,
                data_GN_n2_B1_4, data_GN_n5_B1_4, data_GN_n10_B1_4, x, z1, z2)
#plt.savefig('figures/F4_noise.png', bbox_inches='tight')

# %% [markdown]
# # Plot GS + GN results

# %%
Plot_Models_GSGN(model_true_B1_1, model_GS_B1_1, model_GN_B1_1, model_GSGN_B1_1, x, z1, z2, case='B1-1')
#plt.savefig('figures/B1-1_GSGN.png', bbox_inches='tight')

# %%
Plot_Models_GSGN(model_true_B1_2, model_GS_B1_2, model_GN_B1_2, model_GSGN_B1_2, x, z1, z2, case='B1-2')
#plt.savefig('figures/B1-2_GSGN.png', bbox_inches='tight')

# %%
Plot_Models_GSGN(model_true_B1_3, model_GS_B1_3, model_GN_B1_3, model_GSGN_B1_3, x, z1, z2, case='B1-3')
#plt.savefig('figures/B1-3_GSGN.png', bbox_inches='tight')

# %%
Plot_Models_GSGN(model_true_B1_4, model_GS_B1_4, model_GN_B1_4, model_GSGN_B1_4, x, z1, z2, case='B1-4')
#plt.savefig('figures/B1-4_GSGN.png', bbox_inches='tight')
