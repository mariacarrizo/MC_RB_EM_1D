# %% [markdown]
# # Visualize case A2 results
#
# Date created: 23/04/2024
# Author: @mariacarrizo

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../../src')

from Plots import Plot_Models_2Lay_QIP, Plot_Models_2Lay, Plot_Models_Noise

# %%
# Import Models

model_true_A2_1 = np.load('models/model_synth_2Lay_A2_1.npy')
model_true_A2_2 = np.load('models/model_synth_2Lay_A2_2.npy')
model_true_A2_3 = np.load('models/model_synth_2Lay_A2_3.npy')
model_true_A2_4 = np.load('models/model_synth_2Lay_A2_4.npy')

# Results from global search
model_GS_A2_1 = np.load('results/model_GS_A2_1.npy')
model_GS_A2_2 = np.load('results/model_GS_A2_2.npy')
model_GS_A2_3 = np.load('results/model_GS_A2_3.npy')
model_GS_A2_4 = np.load('results/model_GS_A2_4.npy')

# Results from global search Q
model_GS_Q_A2_1 = np.load('results/model_GS_Q_A2_1.npy')
model_GS_Q_A2_2 = np.load('results/model_GS_Q_A2_2.npy')
model_GS_Q_A2_3 = np.load('results/model_GS_Q_A2_3.npy')
model_GS_Q_A2_4 = np.load('results/model_GS_Q_A2_4.npy')

# Results from global search IP
model_GS_IP_A2_1 = np.load('results/model_GS_IP_A2_1.npy')
model_GS_IP_A2_2 = np.load('results/model_GS_IP_A2_2.npy')
model_GS_IP_A2_3 = np.load('results/model_GS_IP_A2_3.npy')
model_GS_IP_A2_4 = np.load('results/model_GS_IP_A2_4.npy')

# Results from Gauss-Newton
model_GN_A2_1 = np.load('results/model_GN_A2_1.npy')
model_GN_A2_2 = np.load('results/model_GN_A2_2.npy')
model_GN_A2_3 = np.load('results/model_GN_A2_3.npy')
model_GN_A2_4 = np.load('results/model_GN_A2_4.npy')

# Results from Gauss-Newton Q
model_GN_Q_A2_1 = np.load('results/model_GN_Q_A2_1.npy')
model_GN_Q_A2_2 = np.load('results/model_GN_Q_A2_2.npy')
model_GN_Q_A2_3 = np.load('results/model_GN_Q_A2_3.npy')
model_GN_Q_A2_4 = np.load('results/model_GN_Q_A2_4.npy')

# Results from Gauss-Newton IP
model_GN_IP_A2_1 = np.load('results/model_GN_IP_A2_1.npy')
model_GN_IP_A2_2 = np.load('results/model_GN_IP_A2_2.npy')
model_GN_IP_A2_3 = np.load('results/model_GN_IP_A2_3.npy')
model_GN_IP_A2_4 = np.load('results/model_GN_IP_A2_4.npy')

# change electrical conductivity units from S/m to mS/m
model_true_A2_1[:,1:] = model_true_A2_1[:,1:]*1000
model_true_A2_2[:,1:] = model_true_A2_2[:,1:]*1000
model_true_A2_3[:,1:] = model_true_A2_3[:,1:]*1000
model_true_A2_4[:,1:] = model_true_A2_4[:,1:]*1000

model_GS_A2_1[:,1:] = model_GS_A2_1[:,1:]*1000
model_GS_A2_2[:,1:] = model_GS_A2_2[:,1:]*1000
model_GS_A2_3[:,1:] = model_GS_A2_3[:,1:]*1000
model_GS_A2_4[:,1:] = model_GS_A2_4[:,1:]*1000

model_GN_A2_1[:,1:] =  model_GN_A2_1[:,1:]*1000 
model_GN_A2_2[:,1:] =  model_GN_A2_2[:,1:]*1000 
model_GN_A2_3[:,1:] =  model_GN_A2_3[:,1:]*1000 
model_GN_A2_4[:,1:] =  model_GN_A2_4[:,1:]*1000 

model_GS_Q_A2_1[:,1:] = model_GS_Q_A2_1[:,1:]*1000
model_GS_Q_A2_2[:,1:] = model_GS_Q_A2_2[:,1:]*1000
model_GS_Q_A2_3[:,1:] = model_GS_Q_A2_3[:,1:]*1000
model_GS_Q_A2_4[:,1:] = model_GS_Q_A2_4[:,1:]*1000

model_GN_Q_A2_1[:,1:] = model_GN_Q_A2_1[:,1:]*1000
model_GN_Q_A2_2[:,1:] = model_GN_Q_A2_2[:,1:]*1000
model_GN_Q_A2_3[:,1:] = model_GN_Q_A2_3[:,1:]*1000
model_GN_Q_A2_4[:,1:] = model_GN_Q_A2_4[:,1:]*1000

model_GS_IP_A2_1[:,1:] = model_GS_IP_A2_1[:,1:]*1000
model_GS_IP_A2_2[:,1:] = model_GS_IP_A2_2[:,1:]*1000
model_GS_IP_A2_3[:,1:] = model_GS_IP_A2_3[:,1:]*1000
model_GS_IP_A2_4[:,1:] = model_GS_IP_A2_4[:,1:]*1000

model_GN_IP_A2_1[:,1:] = model_GN_IP_A2_1[:,1:]*1000
model_GN_IP_A2_2[:,1:] = model_GN_IP_A2_2[:,1:]*1000
model_GN_IP_A2_3[:,1:] = model_GN_IP_A2_3[:,1:]*1000
model_GN_IP_A2_4[:,1:] = model_GN_IP_A2_4[:,1:]*1000

# %%
# Import true and simulated Data in ppt
data_true_A2_1 = np.load('data/data_synth_2Lay_A2_1.npy')*1000
data_true_A2_2 = np.load('data/data_synth_2Lay_A2_2.npy')*1000
data_true_A2_3 = np.load('data/data_synth_2Lay_A2_3.npy')*1000
data_true_A2_4 = np.load('data/data_synth_2Lay_A2_4.npy')*1000

data_GS_A2_1 = np.load('data/data_GS_A2_1.npy')*1000
data_GS_A2_2 = np.load('data/data_GS_A2_2.npy')*1000
data_GS_A2_3 = np.load('data/data_GS_A2_3.npy')*1000
data_GS_A2_4 = np.load('data/data_GS_A2_4.npy')*1000

data_GS_Q_A2_1 = np.load('data/data_GS_Q_A2_1.npy')*1000
data_GS_Q_A2_2 = np.load('data/data_GS_Q_A2_2.npy')*1000
data_GS_Q_A2_3 = np.load('data/data_GS_Q_A2_3.npy')*1000
data_GS_Q_A2_4 = np.load('data/data_GS_Q_A2_4.npy')*1000

data_GS_IP_A2_1 = np.load('data/data_GS_IP_A2_1.npy')*1000
data_GS_IP_A2_2 = np.load('data/data_GS_IP_A2_2.npy')*1000
data_GS_IP_A2_3 = np.load('data/data_GS_IP_A2_3.npy')*1000
data_GS_IP_A2_4 = np.load('data/data_GS_IP_A2_4.npy')*1000

data_GN_A2_1 = np.load('data/data_GN_A2_1.npy')*1000
data_GN_A2_2 = np.load('data/data_GN_A2_2.npy')*1000
data_GN_A2_3 = np.load('data/data_GN_A2_3.npy')*1000
data_GN_A2_4 = np.load('data/data_GN_A2_4.npy')*1000

data_GN_Q_A2_1 = np.load('data/data_GN_Q_A2_1.npy')*1000
data_GN_Q_A2_2 = np.load('data/data_GN_Q_A2_2.npy')*1000
data_GN_Q_A2_3 = np.load('data/data_GN_Q_A2_3.npy')*1000
data_GN_Q_A2_4 = np.load('data/data_GN_Q_A2_4.npy')*1000

data_GN_IP_A2_1 = np.load('data/data_GN_IP_A2_1.npy')*1000
data_GN_IP_A2_2 = np.load('data/data_GN_IP_A2_2.npy')*1000
data_GN_IP_A2_3 = np.load('data/data_GN_IP_A2_3.npy')*1000
data_GN_IP_A2_4 = np.load('data/data_GN_IP_A2_4.npy')*1000

# %%
# vector of model 1D positions
x = np.linspace(0, len(model_GS_A2_1), len(model_GS_A2_1))

# Depths of first layer in true model
# The depths are identical for all true 2 layered models
z1 = -model_true_A2_1[:,0]

# %% [markdown]
# # Results for models estimated with Q + IP

# %%
Plot_Models_2Lay_QIP(model_true_A2_1, model_GS_A2_1, model_GN_A2_1, data_true_A2_1, data_GS_A2_1, data_GN_A2_1, x, z1,
                 case='A2-1 - [Q + IP]')
#plt.savefig('figures/A2-1_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A2_2, model_GS_A2_2, model_GN_A2_2, data_true_A2_2, data_GS_A2_2, data_GN_A2_2, x, z1,  
                 case='A2-2 - [Q + IP]')
#plt.savefig('figures/A2-2_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A2_3, model_GS_A2_3, model_GN_A2_3, data_true_A2_3, data_GS_A2_3, data_GN_A2_3, x, z1, 
                 case='A2-3 - [Q + IP]')
#plt.savefig('figures/A2-3_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A2_4, model_GS_A2_4, model_GN_A2_4, data_true_A2_4, data_GS_A2_4, data_GN_A2_4, x, z1, 
                 case='A2-4 - [Q + IP]')
#plt.savefig('figures/A2-4_GSvsGN.png', bbox_inches='tight')

# %% [markdown]
# # Results for models estimated with Q

# %%
Plot_Models_2Lay(model_true_A2_1, model_GS_Q_A2_1, model_GN_Q_A2_1, data_true_A2_1[:,:9], data_GS_Q_A2_1, data_GN_Q_A2_1, x, z1,
                    data_type='Quadrature', case='A2-1 - [Q]')
#plt.savefig('figures/A2-1_Q_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_2, model_GS_Q_A2_2, model_GN_Q_A2_2, data_true_A2_2[:,:9], data_GS_Q_A2_2, data_GN_Q_A2_2, x, z1,
                    data_type='Quadrature', case='A2-2 - [Q]')
#plt.savefig('figures/A2-2_Q_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_3, model_GS_Q_A2_3, model_GN_Q_A2_3, data_true_A2_3[:,:9], data_GS_Q_A2_3, data_GN_Q_A2_3, x, z1,
                   data_type='Quadrature', case='A2-3 - [Q]')
#plt.savefig('figures/A2-3_Q_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_4, model_GS_Q_A2_4, model_GN_Q_A2_4, data_true_A2_4[:,:9], data_GS_Q_A2_4, data_GN_Q_A2_4, x, z1,
                   data_type='Quadrature', case='A2-4 - [Q]')
#plt.savefig('figures/A2-4_Q_s.png', bbox_inches='tight')

# %% [markdown]
# # Results of models estimated with IP

# %%
Plot_Models_2Lay(model_true_A2_1, model_GS_IP_A2_1, model_GN_IP_A2_1, data_true_A2_1[:,9:], data_GS_IP_A2_1, data_GN_IP_A2_1, x, z1,
                   data_type='In Phase', case='A2-1 - [IP]')
#plt.savefig('figures/A2-1_IP_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_2, model_GS_IP_A2_2, model_GN_IP_A2_2, data_true_A2_2[:,9:], data_GS_IP_A2_2, data_GN_IP_A2_2, x, z1,
                   data_type='In Phase', case='A2-2 - [IP]')
#plt.savefig('figures/A2-2_IP_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_3, model_GS_IP_A2_3, model_GN_IP_A2_3, data_true_A2_3[:,9:], data_GS_IP_A2_3, data_GN_IP_A2_3, x, z1,
                   data_type='In Phase', case='A2-3 - [IP]')
#plt.savefig('figures/A2-3_IP_s.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A2_4, model_GS_IP_A2_4, model_GN_IP_A2_4, data_true_A2_4[:,9:], data_GS_IP_A2_4, data_GN_IP_A2_4, x, z1,
                   data_type='In Phase', case='A2-4 - [IP]')
#plt.savefig('figures/A2-4_IP_s.png', bbox_inches='tight')

# %% [markdown]
# # Results of models estimated in the presence of noise

# %%
# Load results

# GS
model_GS_n2_A2_1 = np.load('results/model_GS_n2_A2_1.npy')
model_GS_n2_A2_2 = np.load('results/model_GS_n2_A2_2.npy')
model_GS_n2_A2_3 = np.load('results/model_GS_n2_A2_3.npy')
model_GS_n2_A2_4 = np.load('results/model_GS_n2_A2_4.npy')

model_GS_n5_A2_1 = np.load('results/model_GS_n5_A2_1.npy')
model_GS_n5_A2_2 = np.load('results/model_GS_n5_A2_2.npy')
model_GS_n5_A2_3 = np.load('results/model_GS_n5_A2_3.npy')
model_GS_n5_A2_4 = np.load('results/model_GS_n5_A2_4.npy')

model_GS_n10_A2_1 = np.load('results/model_GS_n10_A2_1.npy')
model_GS_n10_A2_2 = np.load('results/model_GS_n10_A2_2.npy')
model_GS_n10_A2_3 = np.load('results/model_GS_n10_A2_3.npy')
model_GS_n10_A2_4 = np.load('results/model_GS_n10_A2_4.npy')

# GN
model_GN_n2_A2_1 = np.load('results/model_n2_GN_A2_1.npy')
model_GN_n2_A2_2 = np.load('results/model_n2_GN_A2_2.npy')
model_GN_n2_A2_3 = np.load('results/model_n2_GN_A2_3.npy')
model_GN_n2_A2_4 = np.load('results/model_n2_GN_A2_4.npy')

model_GN_n5_A2_1 = np.load('results/model_n5_GN_A2_1.npy')
model_GN_n5_A2_2 = np.load('results/model_n5_GN_A2_2.npy')
model_GN_n5_A2_3 = np.load('results/model_n5_GN_A2_3.npy')
model_GN_n5_A2_4 = np.load('results/model_n5_GN_A2_4.npy')

model_GN_n10_A2_1 = np.load('results/model_n10_GN_A2_1.npy')
model_GN_n10_A2_2 = np.load('results/model_n10_GN_A2_2.npy')
model_GN_n10_A2_3 = np.load('results/model_n10_GN_A2_3.npy')
model_GN_n10_A2_4 = np.load('results/model_n10_GN_A2_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GS_n2_A2_1[:,1:] = model_GS_n2_A2_1[:,1:]*1000
model_GS_n2_A2_2[:,1:] = model_GS_n2_A2_2[:,1:]*1000
model_GS_n2_A2_3[:,1:] = model_GS_n2_A2_3[:,1:]*1000
model_GS_n2_A2_4[:,1:] = model_GS_n2_A2_4[:,1:]*1000

model_GS_n5_A2_1[:,1:] = model_GS_n5_A2_1[:,1:]*1000
model_GS_n5_A2_2[:,1:] = model_GS_n5_A2_2[:,1:]*1000
model_GS_n5_A2_3[:,1:] = model_GS_n5_A2_3[:,1:]*1000
model_GS_n5_A2_4[:,1:] = model_GS_n5_A2_4[:,1:]*1000

model_GS_n10_A2_1[:,1:] = model_GS_n10_A2_1[:,1:]*1000
model_GS_n10_A2_2[:,1:] = model_GS_n10_A2_2[:,1:]*1000
model_GS_n10_A2_3[:,1:] = model_GS_n10_A2_3[:,1:]*1000
model_GS_n10_A2_4[:,1:] = model_GS_n10_A2_4[:,1:]*1000

model_GN_n2_A2_1[:,1:] = model_GN_n2_A2_1[:,1:]*1000
model_GN_n2_A2_2[:,1:] = model_GN_n2_A2_2[:,1:]*1000
model_GN_n2_A2_3[:,1:] = model_GN_n2_A2_3[:,1:]*1000
model_GN_n2_A2_4[:,1:] = model_GN_n2_A2_4[:,1:]*1000

model_GN_n5_A2_1[:,1:] = model_GN_n5_A2_1[:,1:]*1000
model_GN_n5_A2_2[:,1:] = model_GN_n5_A2_2[:,1:]*1000
model_GN_n5_A2_3[:,1:] = model_GN_n5_A2_3[:,1:]*1000
model_GN_n5_A2_4[:,1:] = model_GN_n5_A2_4[:,1:]*1000

model_GN_n10_A2_1[:,1:] = model_GN_n10_A2_1[:,1:]*1000
model_GN_n10_A2_2[:,1:] = model_GN_n10_A2_2[:,1:]*1000
model_GN_n10_A2_3[:,1:] = model_GN_n10_A2_3[:,1:]*1000
model_GN_n10_A2_4[:,1:] = model_GN_n10_A2_4[:,1:]*1000

# %%
# Load data

data_true_n2_A2_1 = np.load('data/data_n2_A2_1.npy')*1000
data_true_n2_A2_2 = np.load('data/data_n2_A2_2.npy')*1000
data_true_n2_A2_3 = np.load('data/data_n2_A2_3.npy')*1000
data_true_n2_A2_4 = np.load('data/data_n2_A2_4.npy')*1000

data_true_n5_A2_1 = np.load('data/data_n5_A2_1.npy')*1000
data_true_n5_A2_2 = np.load('data/data_n5_A2_2.npy')*1000
data_true_n5_A2_3 = np.load('data/data_n5_A2_3.npy')*1000
data_true_n5_A2_4 = np.load('data/data_n5_A2_4.npy')*1000

data_true_n10_A2_1 = np.load('data/data_n10_A2_1.npy')*1000
data_true_n10_A2_2 = np.load('data/data_n10_A2_2.npy')*1000
data_true_n10_A2_3 = np.load('data/data_n10_A2_3.npy')*1000
data_true_n10_A2_4 = np.load('data/data_n10_A2_4.npy')*1000

data_GS_n2_A2_1 = np.load('data/data_GS_n2_A2_1.npy')*1000
data_GS_n2_A2_2 = np.load('data/data_GS_n2_A2_2.npy')*1000
data_GS_n2_A2_3 = np.load('data/data_GS_n2_A2_3.npy')*1000
data_GS_n2_A2_4 = np.load('data/data_GS_n2_A2_4.npy')*1000

data_GS_n5_A2_1 = np.load('data/data_GS_n5_A2_1.npy')*1000
data_GS_n5_A2_2 = np.load('data/data_GS_n5_A2_2.npy')*1000
data_GS_n5_A2_3 = np.load('data/data_GS_n5_A2_3.npy')*1000
data_GS_n5_A2_4 = np.load('data/data_GS_n5_A2_4.npy')*1000

data_GS_n10_A2_1 = np.load('data/data_GS_n10_A2_1.npy')*1000
data_GS_n10_A2_2 = np.load('data/data_GS_n10_A2_2.npy')*1000
data_GS_n10_A2_3 = np.load('data/data_GS_n10_A2_3.npy')*1000
data_GS_n10_A2_4 = np.load('data/data_GS_n10_A2_4.npy')*1000

data_GN_n2_A2_1 = np.load('data/data_GN_n2_A2_1.npy')*1000
data_GN_n2_A2_2 = np.load('data/data_GN_n2_A2_2.npy')*1000
data_GN_n2_A2_3 = np.load('data/data_GN_n2_A2_3.npy')*1000
data_GN_n2_A2_4 = np.load('data/data_GN_n2_A2_4.npy')*1000

data_GN_n5_A2_1 = np.load('data/data_GN_n5_A2_1.npy')*1000
data_GN_n5_A2_2 = np.load('data/data_GN_n5_A2_2.npy')*1000
data_GN_n5_A2_3 = np.load('data/data_GN_n5_A2_3.npy')*1000
data_GN_n5_A2_4 = np.load('data/data_GN_n5_A2_4.npy')*1000

data_GN_n10_A2_1 = np.load('data/data_GN_n10_A2_1.npy')*1000
data_GN_n10_A2_2 = np.load('data/data_GN_n10_A2_2.npy')*1000
data_GN_n10_A2_3 = np.load('data/data_GN_n10_A2_3.npy')*1000
data_GN_n10_A2_4 = np.load('data/data_GN_n10_A2_4.npy')*1000

# %%
Plot_Models_Noise(model_true_A2_1, model_GS_n2_A2_1, model_GS_n5_A2_1, model_GS_n10_A2_1,
                  model_GN_n2_A2_1, model_GN_n5_A2_1, model_GN_n10_A2_1 ,
                  data_true_A2_1, data_GS_n2_A2_1, data_GS_n5_A2_1, data_GS_n10_A2_1,
                  data_GN_n2_A2_1, data_GN_n5_A2_1, data_GN_n10_A2_1, x, z1)
#plt.savefig('figures/A2-1_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A2_2, model_GS_n2_A2_2, model_GS_n5_A2_2, model_GS_n10_A2_2,
                  model_GN_n2_A2_2, model_GN_n5_A2_2, model_GN_n10_A2_2,
                  data_true_A2_2, data_GS_n2_A2_2, data_GS_n5_A2_2, data_GS_n10_A2_2,
                  data_GN_n2_A2_2, data_GN_n5_A2_2, data_GN_n10_A2_2, x, z1)
#plt.savefig('figures/A2-2_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A2_3, model_GS_n2_A2_3, model_GS_n5_A2_3, model_GS_n10_A2_3,
                  model_GN_n2_A2_3, model_GN_n5_A2_3, model_GN_n10_A2_3,
                  data_true_A2_3, data_GS_n2_A2_3, data_GS_n5_A2_3, data_GS_n10_A2_3,
                  data_GN_n2_A2_3, data_GN_n5_A2_3, data_GN_n10_A2_3, x, z1)
#plt.savefig('figures/A2-3_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A2_4, model_GS_n2_A2_4, model_GS_n5_A2_4, model_GS_n10_A2_4,
                  model_GN_n2_A2_4, model_GN_n5_A2_4, model_GN_n10_A2_4,
                  data_true_A2_4, data_GS_n2_A2_4, data_GS_n5_A2_4, data_GS_n10_A2_4,
                  data_GN_n2_A2_4, data_GN_n5_A2_4, data_GN_n10_A2_4, x, z1)
#plt.savefig('figures/A2-4_noise.png', bbox_inches='tight')
