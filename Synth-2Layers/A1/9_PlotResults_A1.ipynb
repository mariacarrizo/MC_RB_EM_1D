# %% [markdown]
# # Visualize case A1 results
#
# Date created: 23/04/2024
# Author: @mariacarrizo

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../../src')

# Insert functions
from Plots import Plot_Models_2Lay_QIP, Plot_Models_2Lay, Plot_Models_Noise
from EM1D import EMf_2Lay_HVP

# %%
# Import Models

# True models
model_true_A1_1 = np.load('models/model_synth_2Lay_A1_1.npy')
model_true_A1_2 = np.load('models/model_synth_2Lay_A1_2.npy')
model_true_A1_3 = np.load('models/model_synth_2Lay_A1_3.npy')
model_true_A1_4 = np.load('models/model_synth_2Lay_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_true_A1_1[:,1:] = model_true_A1_1[:,1:]*1000
model_true_A1_2[:,1:] = model_true_A1_2[:,1:]*1000
model_true_A1_3[:,1:] = model_true_A1_3[:,1:]*1000
model_true_A1_4[:,1:] = model_true_A1_4[:,1:]*1000

# Results from global search
model_GS_A1_1 = np.load('results/model_GS_A1_1.npy')
model_GS_A1_2 = np.load('results/model_GS_A1_2.npy')
model_GS_A1_3 = np.load('results/model_GS_A1_3.npy')
model_GS_A1_4 = np.load('results/model_GS_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GS_A1_1[:,1:] = model_GS_A1_1[:,1:]*1000
model_GS_A1_2[:,1:] = model_GS_A1_2[:,1:]*1000
model_GS_A1_3[:,1:] = model_GS_A1_3[:,1:]*1000
model_GS_A1_4[:,1:] = model_GS_A1_4[:,1:]*1000

# Results from Gauss-Newton
model_GN_A1_1 = np.load('results/model_GN_A1_1.npy')
model_GN_A1_2 = np.load('results/model_GN_A1_2.npy')
model_GN_A1_3 = np.load('results/model_GN_A1_3.npy')
model_GN_A1_4 = np.load('results/model_GN_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GN_A1_1[:,1:] =  model_GN_A1_1[:,1:]*1000 
model_GN_A1_2[:,1:] =  model_GN_A1_2[:,1:]*1000 
model_GN_A1_3[:,1:] =  model_GN_A1_3[:,1:]*1000 
model_GN_A1_4[:,1:] =  model_GN_A1_4[:,1:]*1000 

# Results from global search Q
model_GS_Q_A1_1 = np.load('results/model_GS_Q_A1_1.npy')
model_GS_Q_A1_2 = np.load('results/model_GS_Q_A1_2.npy')
model_GS_Q_A1_3 = np.load('results/model_GS_Q_A1_3.npy')
model_GS_Q_A1_4 = np.load('results/model_GS_Q_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GS_Q_A1_1[:,1:] = model_GS_Q_A1_1[:,1:]*1000
model_GS_Q_A1_2[:,1:] = model_GS_Q_A1_2[:,1:]*1000
model_GS_Q_A1_3[:,1:] = model_GS_Q_A1_3[:,1:]*1000
model_GS_Q_A1_4[:,1:] = model_GS_Q_A1_4[:,1:]*1000

# Results from Gauss-Newton Q
model_GN_Q_A1_1 = np.load('results/model_GN_Q_A1_1.npy')
model_GN_Q_A1_2 = np.load('results/model_GN_Q_A1_2.npy')
model_GN_Q_A1_3 = np.load('results/model_GN_Q_A1_3.npy')
model_GN_Q_A1_4 = np.load('results/model_GN_Q_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GN_Q_A1_1[:,1:] = model_GN_Q_A1_1[:,1:]*1000
model_GN_Q_A1_2[:,1:] = model_GN_Q_A1_2[:,1:]*1000
model_GN_Q_A1_3[:,1:] = model_GN_Q_A1_3[:,1:]*1000
model_GN_Q_A1_4[:,1:] = model_GN_Q_A1_4[:,1:]*1000

# Results from global search IP
model_GS_IP_A1_1 = np.load('results/model_GS_IP_A1_1.npy')
model_GS_IP_A1_2 = np.load('results/model_GS_IP_A1_2.npy')
model_GS_IP_A1_3 = np.load('results/model_GS_IP_A1_3.npy')
model_GS_IP_A1_4 = np.load('results/model_GS_IP_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GS_IP_A1_1[:,1:] = model_GS_IP_A1_1[:,1:]*1000
model_GS_IP_A1_2[:,1:] = model_GS_IP_A1_2[:,1:]*1000
model_GS_IP_A1_3[:,1:] = model_GS_IP_A1_3[:,1:]*1000
model_GS_IP_A1_4[:,1:] = model_GS_IP_A1_4[:,1:]*1000

# Results from Gauss-Newton IP
model_GN_IP_A1_1 = np.load('results/model_GN_IP_A1_1.npy')
model_GN_IP_A1_2 = np.load('results/model_GN_IP_A1_2.npy')
model_GN_IP_A1_3 = np.load('results/model_GN_IP_A1_3.npy')
model_GN_IP_A1_4 = np.load('results/model_GN_IP_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GN_IP_A1_1[:,1:] = model_GN_IP_A1_1[:,1:]*1000
model_GN_IP_A1_2[:,1:] = model_GN_IP_A1_2[:,1:]*1000
model_GN_IP_A1_3[:,1:] = model_GN_IP_A1_3[:,1:]*1000
model_GN_IP_A1_4[:,1:] = model_GN_IP_A1_4[:,1:]*1000

# %%
# Import true and simulated Data
# multiply by 1000 to obtain data in ppt
data_true_A1_1 = np.load('data/data_synth_2Lay_A1_1.npy')*1000
data_true_A1_2 = np.load('data/data_synth_2Lay_A1_2.npy')*1000
data_true_A1_3 = np.load('data/data_synth_2Lay_A1_3.npy')*1000
data_true_A1_4 = np.load('data/data_synth_2Lay_A1_4.npy')*1000

data_GS_A1_1 = np.load('data/data_GS_A1_1.npy')*1000
data_GS_A1_2 = np.load('data/data_GS_A1_2.npy')*1000
data_GS_A1_3 = np.load('data/data_GS_A1_3.npy')*1000
data_GS_A1_4 = np.load('data/data_GS_A1_4.npy')*1000

data_GS_Q_A1_1 = np.load('data/data_GS_Q_A1_1.npy')*1000
data_GS_Q_A1_2 = np.load('data/data_GS_Q_A1_2.npy')*1000
data_GS_Q_A1_3 = np.load('data/data_GS_Q_A1_3.npy')*1000
data_GS_Q_A1_4 = np.load('data/data_GS_Q_A1_4.npy')*1000

data_GS_IP_A1_1 = np.load('data/data_GS_IP_A1_1.npy')*1000
data_GS_IP_A1_2 = np.load('data/data_GS_IP_A1_2.npy')*1000
data_GS_IP_A1_3 = np.load('data/data_GS_IP_A1_3.npy')*1000
data_GS_IP_A1_4 = np.load('data/data_GS_IP_A1_4.npy')*1000

data_GN_A1_1 = np.load('data/data_GN_A1_1.npy')*1000
data_GN_A1_2 = np.load('data/data_GN_A1_2.npy')*1000
data_GN_A1_3 = np.load('data/data_GN_A1_3.npy')*1000
data_GN_A1_4 = np.load('data/data_GN_A1_4.npy')*1000

data_GN_Q_A1_1 = np.load('data/data_GN_Q_A1_1.npy')*1000
data_GN_Q_A1_2 = np.load('data/data_GN_Q_A1_2.npy')*1000
data_GN_Q_A1_3 = np.load('data/data_GN_Q_A1_3.npy')*1000
data_GN_Q_A1_4 = np.load('data/data_GN_Q_A1_4.npy')*1000

data_GN_IP_A1_1 = np.load('data/data_GN_IP_A1_1.npy')*1000
data_GN_IP_A1_2 = np.load('data/data_GN_IP_A1_2.npy')*1000
data_GN_IP_A1_3 = np.load('data/data_GN_IP_A1_3.npy')*1000
data_GN_IP_A1_4 = np.load('data/data_GN_IP_A1_4.npy')*1000

# %%
# vector of model 1D positions
x = np.linspace(0, len(model_GS_A1_1), len(model_GS_A1_1))

# Depths of first layer in true model
# The depths are identical for all true 2 layered models
z1 = -model_true_A1_1[:,0]

# %% [markdown]
# # Results for models estimated with Q + IP

# %%
Plot_Models_2Lay_QIP(model_true_A1_1, model_GS_A1_1, model_GN_A1_1, data_true_A1_1, data_GS_A1_1, data_GN_A1_1, x, z1,
            case='A1-1 - [Q + IP]')
#plt.savefig('figures/A1-1_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A1_2, model_GS_A1_2, model_GN_A1_2, data_true_A1_2, data_GS_A1_2, data_GN_A1_2, x, z1,
            case='A1-2 - [Q + IP]')
#plt.savefig('figures/A1-2_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A1_3, model_GS_A1_3, model_GN_A1_3, data_true_A1_3, data_GS_A1_3, data_GN_A1_3, x, z1,
            case='A1-3 - [Q + IP]')
#plt.savefig('figures/A1-3_GSvsGN.png', bbox_inches='tight')

# %%
Plot_Models_2Lay_QIP(model_true_A1_4, model_GS_A1_4, model_GN_A1_4, data_true_A1_4, data_GS_A1_4, data_GN_A1_4, x, z1,
            case='A1-4 - [Q + IP]')
#plt.savefig('figures/A1-4_GSvsGN.png', bbox_inches='tight')

# %% [markdown]
# # Results for models estimated with Q

# %%
Plot_Models_2Lay(model_true_A1_1, model_GS_Q_A1_1, model_GN_Q_A1_1, data_true_A1_1[:,:9], data_GS_Q_A1_1, data_GN_Q_A1_1, x, z1,
                 data_type='Quadrature', case='A1-1 - [Q]')
#plt.savefig('figures/A1-1_Q.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_2, model_GS_Q_A1_2, model_GN_Q_A1_2, data_true_A1_2[:,:9], data_GS_Q_A1_2, data_GN_Q_A1_2, x, z1,
                 data_type='Quadrature', case='A1-2 - [Q]')
#plt.savefig('figures/A1-2_Q.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_3, model_GS_Q_A1_3, model_GN_Q_A1_3, data_true_A1_3[:,:9], data_GS_Q_A1_3, data_GN_Q_A1_3, x, z1, 
                 data_type='Quadrature', case='A1-3 - [Q]')
#plt.savefig('figures/A1-3_Q.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_4, model_GS_Q_A1_4, model_GN_Q_A1_4, data_true_A1_4[:,:9], data_GS_Q_A1_4, data_GN_Q_A1_4, x, z1,
                 data_type='Quadrature', case='A1-4 - [Q]')
#plt.savefig('figures/A1-4_Q.png', bbox_inches='tight')

# %% [markdown]
# # Results of models estimated with IP

# %%
Plot_Models_2Lay(model_true_A1_1, model_GS_IP_A1_1, model_GN_IP_A1_1, data_true_A1_1[:,9:], data_GS_IP_A1_1, data_GN_IP_A1_1, x, z1,
                    data_type='In Phase', case='A1-1 - [IP]')
#plt.savefig('figures/A1-1_IP.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_2, model_GS_IP_A1_2, model_GN_IP_A1_2, data_true_A1_2[:,9:], data_GS_IP_A1_2, data_GN_IP_A1_2, x, z1, 
                 data_type='In Phase', case='A1-2 - [IP]')
#plt.savefig('figures/A1-2_IP.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_3, model_GS_IP_A1_3, model_GN_IP_A1_3, data_true_A1_3[:,9:], data_GS_IP_A1_3, data_GN_IP_A1_3, x, z1, 
                 data_type='In Phase', case='A1-3 - [IP]')
#plt.savefig('figures/A1-3_IP.png', bbox_inches='tight')

# %%
Plot_Models_2Lay(model_true_A1_4, model_GS_IP_A1_4, model_GN_IP_A1_4, data_true_A1_4[:,9:], data_GS_IP_A1_4, data_GN_IP_A1_4, x, z1,
                 data_type='In Phase', case='A1-4 - [IP]')
#plt.savefig('figures/A1-4_IP.png', bbox_inches='tight')

# %% [markdown]
# # Results of models estimated in presence of noise

# %%
# Load results

# GS 
model_GS_n2_A1_1 = np.load('results/model_GS_n2_A1_1.npy')
model_GS_n2_A1_2 = np.load('results/model_GS_n2_A1_2.npy')
model_GS_n2_A1_3 = np.load('results/model_GS_n2_A1_3.npy')
model_GS_n2_A1_4 = np.load('results/model_GS_n2_A1_4.npy')

model_GS_n5_A1_1 = np.load('results/model_GS_n5_A1_1.npy')
model_GS_n5_A1_2 = np.load('results/model_GS_n5_A1_2.npy')
model_GS_n5_A1_3 = np.load('results/model_GS_n5_A1_3.npy')
model_GS_n5_A1_4 = np.load('results/model_GS_n5_A1_4.npy')

model_GS_n10_A1_1 = np.load('results/model_GS_n10_A1_1.npy')
model_GS_n10_A1_2 = np.load('results/model_GS_n10_A1_2.npy')
model_GS_n10_A1_3 = np.load('results/model_GS_n10_A1_3.npy')
model_GS_n10_A1_4 = np.load('results/model_GS_n10_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GS_n2_A1_1[:,1:] = model_GS_n2_A1_1[:,1:]*1000
model_GS_n2_A1_2[:,1:] = model_GS_n2_A1_2[:,1:]*1000
model_GS_n2_A1_3[:,1:] = model_GS_n2_A1_3[:,1:]*1000
model_GS_n2_A1_4[:,1:] = model_GS_n2_A1_4[:,1:]*1000

model_GS_n5_A1_1[:,1:] = model_GS_n5_A1_1[:,1:]*1000
model_GS_n5_A1_2[:,1:] = model_GS_n5_A1_2[:,1:]*1000
model_GS_n5_A1_3[:,1:] = model_GS_n5_A1_3[:,1:]*1000
model_GS_n5_A1_4[:,1:] = model_GS_n5_A1_4[:,1:]*1000

model_GS_n10_A1_1[:,1:] = model_GS_n10_A1_1[:,1:]*1000
model_GS_n10_A1_2[:,1:] = model_GS_n10_A1_2[:,1:]*1000
model_GS_n10_A1_3[:,1:] = model_GS_n10_A1_3[:,1:]*1000
model_GS_n10_A1_4[:,1:] = model_GS_n10_A1_4[:,1:]*1000

# GN
model_GN_n2_A1_1 = np.load('results/model_n2_GN_A1_1.npy')
model_GN_n2_A1_2 = np.load('results/model_n2_GN_A1_2.npy')
model_GN_n2_A1_3 = np.load('results/model_n2_GN_A1_3.npy')
model_GN_n2_A1_4 = np.load('results/model_n2_GN_A1_4.npy')

model_GN_n5_A1_1 = np.load('results/model_n5_GN_A1_1.npy')
model_GN_n5_A1_2 = np.load('results/model_n5_GN_A1_2.npy')
model_GN_n5_A1_3 = np.load('results/model_n5_GN_A1_3.npy')
model_GN_n5_A1_4 = np.load('results/model_n5_GN_A1_4.npy')

model_GN_n10_A1_1 = np.load('results/model_n10_GN_A1_1.npy')
model_GN_n10_A1_2 = np.load('results/model_n10_GN_A1_2.npy')
model_GN_n10_A1_3 = np.load('results/model_n10_GN_A1_3.npy')
model_GN_n10_A1_4 = np.load('results/model_n10_GN_A1_4.npy')

# change electrical conductivity units from S/m to mS/m
model_GN_n2_A1_1[:,1:] = model_GN_n2_A1_1[:,1:]*1000
model_GN_n2_A1_2[:,1:] = model_GN_n2_A1_2[:,1:]*1000
model_GN_n2_A1_3[:,1:] = model_GN_n2_A1_3[:,1:]*1000
model_GN_n2_A1_4[:,1:] = model_GN_n2_A1_4[:,1:]*1000

model_GN_n5_A1_1[:,1:] = model_GN_n5_A1_1[:,1:]*1000
model_GN_n5_A1_2[:,1:] = model_GN_n5_A1_2[:,1:]*1000
model_GN_n5_A1_3[:,1:] = model_GN_n5_A1_3[:,1:]*1000
model_GN_n5_A1_4[:,1:] = model_GN_n5_A1_4[:,1:]*1000

model_GN_n10_A1_1[:,1:] = model_GN_n10_A1_1[:,1:]*1000
model_GN_n10_A1_2[:,1:] = model_GN_n10_A1_2[:,1:]*1000
model_GN_n10_A1_3[:,1:] = model_GN_n10_A1_3[:,1:]*1000
model_GN_n10_A1_4[:,1:] = model_GN_n10_A1_4[:,1:]*1000

# %%
# Load data with noise included in ppt

data_true_n2_A1_1 = np.load('data/data_n2_A1_1.npy')*1000
data_true_n2_A1_2 = np.load('data/data_n2_A1_2.npy')*1000
data_true_n2_A1_3 = np.load('data/data_n2_A1_3.npy')*1000
data_true_n2_A1_4 = np.load('data/data_n2_A1_4.npy')*1000

data_true_n5_A1_1 = np.load('data/data_n5_A1_1.npy')*1000
data_true_n5_A1_2 = np.load('data/data_n5_A1_2.npy')*1000
data_true_n5_A1_3 = np.load('data/data_n5_A1_3.npy')*1000
data_true_n5_A1_4 = np.load('data/data_n5_A1_4.npy')*1000

data_true_n10_A1_1 = np.load('data/data_n10_A1_1.npy')*1000
data_true_n10_A1_2 = np.load('data/data_n10_A1_2.npy')*1000
data_true_n10_A1_3 = np.load('data/data_n10_A1_3.npy')*1000
data_true_n10_A1_4 = np.load('data/data_n10_A1_4.npy')*1000

# simulated data for models estimated with noise included in ppt
data_GS_n2_A1_1 = np.load('data/data_GS_n2_A1_1.npy')*1000
data_GS_n2_A1_2 = np.load('data/data_GS_n2_A1_2.npy')*1000
data_GS_n2_A1_3 = np.load('data/data_GS_n2_A1_3.npy')*1000
data_GS_n2_A1_4 = np.load('data/data_GS_n2_A1_4.npy')*1000

data_GS_n5_A1_1 = np.load('data/data_GS_n5_A1_1.npy')*1000
data_GS_n5_A1_2 = np.load('data/data_GS_n5_A1_2.npy')*1000
data_GS_n5_A1_3 = np.load('data/data_GS_n5_A1_3.npy')*1000
data_GS_n5_A1_4 = np.load('data/data_GS_n5_A1_4.npy')*1000

data_GS_n10_A1_1 = np.load('data/data_GS_n10_A1_1.npy')*1000
data_GS_n10_A1_2 = np.load('data/data_GS_n10_A1_2.npy')*1000
data_GS_n10_A1_3 = np.load('data/data_GS_n10_A1_3.npy')*1000
data_GS_n10_A1_4 = np.load('data/data_GS_n10_A1_4.npy')*1000

data_GN_n2_A1_1 = np.load('data/data_GN_n2_A1_1.npy')*1000
data_GN_n2_A1_2 = np.load('data/data_GN_n2_A1_2.npy')*1000
data_GN_n2_A1_3 = np.load('data/data_GN_n2_A1_3.npy')*1000
data_GN_n2_A1_4 = np.load('data/data_GN_n2_A1_4.npy')*1000

data_GN_n5_A1_1 = np.load('data/data_GN_n5_A1_1.npy')*1000
data_GN_n5_A1_2 = np.load('data/data_GN_n5_A1_2.npy')*1000
data_GN_n5_A1_3 = np.load('data/data_GN_n5_A1_3.npy')*1000
data_GN_n5_A1_4 = np.load('data/data_GN_n5_A1_4.npy')*1000

data_GN_n10_A1_1 = np.load('data/data_GN_n10_A1_1.npy')*1000
data_GN_n10_A1_2 = np.load('data/data_GN_n10_A1_2.npy')*1000
data_GN_n10_A1_3 = np.load('data/data_GN_n10_A1_3.npy')*1000
data_GN_n10_A1_4 = np.load('data/data_GN_n10_A1_4.npy')*1000

# %%
Plot_Models_Noise(model_true_A1_1, model_GS_n2_A1_1, model_GS_n5_A1_1, model_GS_n10_A1_1,
                  model_GN_n2_A1_1, model_GN_n5_A1_1, model_GN_n10_A1_1 ,
                  data_true_A1_1, data_GS_n2_A1_1, data_GS_n5_A1_1, data_GS_n10_A1_1,
                  data_GN_n2_A1_1, data_GN_n5_A1_1, data_GN_n10_A1_1, x, z1)
#plt.savefig('figures/A1-1_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A1_2, model_GS_n2_A1_2, model_GS_n5_A1_2, model_GS_n10_A1_2,
                  model_GN_n2_A1_2, model_GN_n5_A1_2, model_GN_n10_A1_2,
                  data_true_A1_2, data_GS_n2_A1_2, data_GS_n5_A1_2, data_GS_n10_A1_2,
                  data_GN_n2_A1_2, data_GN_n5_A1_2, data_GN_n10_A1_2, x, z1)
#plt.savefig('figures/A1-2_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A1_3, model_GS_n2_A1_3, model_GS_n5_A1_3, model_GS_n10_A1_3,
                  model_GN_n2_A1_3, model_GN_n5_A1_3, model_GN_n10_A1_3,
                  data_true_A1_3, data_GS_n2_A1_3, data_GS_n5_A1_3, data_GS_n10_A1_3,
                  data_GN_n2_A1_3, data_GN_n5_A1_3, data_GN_n10_A1_3, x, z1)
#plt.savefig('figures/A1-3_noise.png', bbox_inches='tight')

# %%
Plot_Models_Noise(model_true_A1_4, model_GS_n2_A1_4, model_GS_n5_A1_4, model_GS_n10_A1_4,
                  model_GN_n2_A1_4, model_GN_n5_A1_4, model_GN_n10_A1_4,
                  data_true_A1_4, data_GS_n2_A1_4, data_GS_n5_A1_4, data_GS_n10_A1_4,
                  data_GN_n2_A1_4, data_GN_n5_A1_4, data_GN_n10_A1_4, x, z1)
#plt.savefig('figures/A1-4_noise.png', bbox_inches='tight')
