# %%
# %matplotlib widget

# %% [markdown]
# # Visualize case A1 results
#
# Date created: 23/04/2024
# Author: @mariacarrizo

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import pandas as pd
import pygimli as pg
import sys
sys.path.insert(1, '../../src')

from Plots import showStitchedModels

# %%
# Import Models

model_true_A1_1 = np.load('models/model_synth_2Lay_A1_1.npy')
model_true_A1_2 = np.load('models/model_synth_2Lay_A1_2.npy')
model_true_A1_3 = np.load('models/model_synth_2Lay_A1_3.npy')
model_true_A1_4 = np.load('models/model_synth_2Lay_A1_4.npy')

# Results from global search
model_GS_A1_1 = np.load('results/model_2Lay_A1_1.npy')
model_GS_A1_2 = np.load('results/model_2Lay_A1_2.npy')
model_GS_A1_3 = np.load('results/model_2Lay_A1_3.npy')
model_GS_A1_4 = np.load('results/model_2Lay_A1_4.npy')

# Results from optimization
model_Opt_A1_1 = np.load('results/model_Opt_A1_1.npy')
model_Opt_A1_2 = np.load('results/model_Opt_A1_2.npy')
model_Opt_A1_3 = np.load('results/model_Opt_A1_3.npy')
model_Opt_A1_4 = np.load('results/model_Opt_A1_4.npy')

# Import Data
data_true_A1_1 = np.load('data/data_synth_2Lay_A1_1.npy')
data_true_A1_2 = np.load('data/data_synth_2Lay_A1_2.npy')
data_true_A1_3 = np.load('data/data_synth_2Lay_A1_3.npy')
data_true_A1_4 = np.load('data/data_synth_2Lay_A1_4.npy')

# %%
inputs = {
    'colorBar':False,
    'cMin':10/1000,
    'cMax':1800/1000,
    'zMax':8,
    'cMap':'Spectral_r'
}

fig, ax = plt.subplots(4,3, sharex=True, sharey=True)

showStitchedModels(model_true_A1_1, ax = ax[0,0], **inputs)
showStitchedModels(model_true_A1_2, ax = ax[1,0], **inputs)
showStitchedModels(model_true_A1_3, ax = ax[2,0], **inputs)
showStitchedModels(model_true_A1_4, ax = ax[3,0], **inputs)

showStitchedModels(model_GS_A1_1, ax = ax[0,1], **inputs)
showStitchedModels(model_GS_A1_2, ax = ax[1,1], **inputs)
showStitchedModels(model_GS_A1_3, ax = ax[2,1], **inputs)
showStitchedModels(model_GS_A1_4, ax = ax[3,1], **inputs)

showStitchedModels(model_Opt_A1_1, ax = ax[0,2], **inputs)
showStitchedModels(model_Opt_A1_2, ax = ax[1,2], **inputs)
showStitchedModels(model_Opt_A1_3, ax = ax[2,2], **inputs)
showStitchedModels(model_Opt_A1_4, ax = ax[3,2], **inputs)
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
